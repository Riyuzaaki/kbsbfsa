# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("Train_data.csv")
test=pd.read_csv("Test_data.csv")

# %%
train.drop(['accident'],axis=1,inplace=True)

# %%
train
# Out:
#        Unnamed: 0 code clientType registrationMode planName  duration  \
# 0               1  CBH      Basic          Offline        M       186
# 1               2  CBH      Basic          Offline        M       186
# 2               3  CWT      Basic           Online        Q        65
# 3               4  CWT      Basic           Online        Q        60
# 4               5  CWT      Basic           Online        Q        79
# ...           ...  ...        ...              ...      ...       ...
# 60321       60322  JZI    Premium           Online        I       111
# 60322       60323  JZI    Premium           Online        I        58
# 60323       60324  JZI    Premium           Online        I         2
# 60324       60325  JZI    Premium           Online        I         3
# 60325       60326  JZI    Premium           Online        I        22
#
#          country  netSales  netProfit gender  age
# 0       MALAYSIA     -29.0       9.57      F   81
# ...

# %%
test
# Out:
#       Unnamed: 0 code clientType registrationMode planName  duration  \
# 0          42104  EPX      Basic           Online        B        24
# 1            869  EPX      Basic           Online        K        52
# 2          57025  CWT      Basic           Online        Q         6
# 3           1148  EPX      Basic           Online        K        37
# 4          23356  CWT      Basic           Online        Q        77
# ...          ...  ...        ...              ...      ...       ...
# 2995       58310  EPX      Basic           Online        K         3
# 2996        5892  EPX      Basic           Online        K        10
# 2997       23746  SSI    Premium           Online        W        16
# 2998        3667  EPX      Basic           Online        B         7
# 2999       62919  EPX      Basic           Online        A        19
#
#           country  netSales  netProfit gender  age
# 0           INDIA     26.00       0.00    NaN   36
# ...

# %%
vertical_stack = pd.concat([train, test], axis=0)

# %%
vertical_stack
# Out:
#       Unnamed: 0 code clientType registrationMode planName  duration  \
# 0              1  CBH      Basic          Offline        M       186
# 1              2  CBH      Basic          Offline        M       186
# 2              3  CWT      Basic           Online        Q        65
# 3              4  CWT      Basic           Online        Q        60
# 4              5  CWT      Basic           Online        Q        79
# ...          ...  ...        ...              ...      ...       ...
# 2995       58310  EPX      Basic           Online        K         3
# 2996        5892  EPX      Basic           Online        K        10
# 2997       23746  SSI    Premium           Online        W        16
# 2998        3667  EPX      Basic           Online        B         7
# 2999       62919  EPX      Basic           Online        A        19
#
#           country  netSales  netProfit gender  age
# 0        MALAYSIA    -29.00       9.57      F   81
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
code=le.fit_transform(vertical_stack['code'].values)
code
# Out:
# array([ 3,  3,  6, ..., 13,  7,  7])

# %%
clientType=le.fit_transform(vertical_stack['clientType'].values)
clientType
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
registrationMode=le.fit_transform(vertical_stack['registrationMode'].values)
registrationMode
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
planName=le.fit_transform(vertical_stack['planName'].values)
planName
# Out:
# array([12, 12, 16, ..., 22,  1,  0])

# %%
country=le.fit_transform(vertical_stack['country'].values)
country
# Out:
# array([ 79,  79,   4, ..., 118, 102, 118])

# %%
x=pd.DataFrame()
x['code']=code
x['clientType']=clientType
x['registrationMode']=registrationMode
x['planName']=planName
x['country']=country

# %%
x
# Out:
#        code  clientType  registrationMode  planName  country
# 0         3           0                 0        12       79
# 1         3           0                 0        12       79
# 2         6           0                 1        16        4
# 3         6           0                 1        16        4
# 4         6           0                 1        16       61
# ...     ...         ...               ...       ...      ...
# 63321     7           0                 1        10       26
# 63322     7           0                 1        10        4
# 63323    13           1                 1        22      118
# 63324     7           0                 1         1      102
# 63325     7           0                 1         0      118
#
# [63326 rows x 5 columns]

# %%
x['duration']=np.array(vertical_stack['duration'])
x['age']=np.array(vertical_stack['age'])

# %%
x
# Out:
#        code  clientType  registrationMode  planName  country  duration  age
# 0         3           0                 0        12       79       186   81
# 1         3           0                 0        12       79       186   71
# 2         6           0                 1        16        4        65   32
# 3         6           0                 1        16        4        60   32
# 4         6           0                 1        16       61        79   41
# ...     ...         ...               ...       ...      ...       ...  ...
# 63321     7           0                 1        10       26         3   35
# 63322     7           0                 1        10        4        10   36
# 63323    13           1                 1        22      118        16   48
# 63324     7           0                 1         1      102         7   39
# 63325     7           0                 1         0      118        19   37
#
# [63326 rows x 7 columns]

# %%
x_train=x[:60326]

# %%
x_test=x[60326:]

# %%
ykeliy=pd.read_csv("Train_data.csv")
ykeliy
# Out:
#        Unnamed: 0 code clientType registrationMode planName  accident  \
# 0               1  CBH      Basic          Offline        M         0
# 1               2  CBH      Basic          Offline        M         0
# 2               3  CWT      Basic           Online        Q         0
# 3               4  CWT      Basic           Online        Q         0
# 4               5  CWT      Basic           Online        Q         0
# ...           ...  ...        ...              ...      ...       ...
# 60321       60322  JZI    Premium           Online        I         0
# 60322       60323  JZI    Premium           Online        I         0
# 60323       60324  JZI    Premium           Online        I         0
# 60324       60325  JZI    Premium           Online        I         0
# 60325       60326  JZI    Premium           Online        I         0
#
#        duration    country  netSales  netProfit gender  age
# 0           186   MALAYSIA     -29.0       9.57      F   81
# ...

# %%
y_train=ykeliy['accident']

# %%
x_train.isnull().sum()
# Out:
# code                0
# clientType          0
# registrationMode    0
# planName            0
# country             0
# duration            0
# age                 0
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
x_test.isnull().sum()
# Out:
# code                0
# clientType          0
# registrationMode    0
# planName            0
# country             0
# duration            0
# age                 0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100)

# %%
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
result=pd.DataFrame()
result['accident']=y_pred

# %%
result.to_csv('result.txt', sep='\n', index=False, header=False)

# %%
abz=pd.read_csv("sample_output.txt")
abc=pd.read_csv("result.txt")

# %%
abz
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 2994  0
# 2995  0
# 2996  0
# 2997  0
# 2998  0
#
# [2999 rows x 1 columns]

# %%
abc
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 2994  0
# 2995  0
# 2996  0
# 2997  0
# 2998  0
#
# [2999 rows x 1 columns]
